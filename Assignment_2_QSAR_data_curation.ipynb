# %% [markdown]
# # **AI And Biotechnology/Bioinformatics**
#
# ## **AI and Drug Discovery Course: QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# **First we need to connect Google Colab with our Google Drive, so that we can have access to our Google drive within Colab.**
#
# This allows us to:
# * Save datasets
# * Reload data across sessions
# * Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Now create "data" folder in our "Colab Notebooks" folder on Google Drive.**

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %% [markdown]
# ## Install and Import Required Libraries
# We install the ChEMBL web service package so that we can retrieve bioactivity data

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.3 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.7 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 6.1 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %% [markdown]
# # Import Libraries
# * pandas for data handling
# * new_client from chembl for accessing the database

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # **Step 1: Search for Traget Protein**
#
# ## **Target Identification (KLK3)**
# Search ChEMBL for the KLK3 target and select the most relevant entry.

# %%
target = new_client.target
target_query = target.search("KLK3")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references           organism  \
# 0               []       Homo sapiens
# 1               []       Homo sapiens
# 2               []       Mus musculus
# 3               []  Rattus norvegicus
# 4               []       Homo sapiens
#
#                                     pref_name  score  species_group_flag  \
# 0                           Plasma kallikrein   14.0               False
# 1                   Prostate-specific antigen   14.0               False
# 2                           Plasma kallikrein   14.0               False
# 3                           Plasma kallikrein   14.0               False
# 4  Coagulation factor X and plasma kallikrein   10.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL2000  [{'accession': 'P03952', 'component_descriptio...
# 1       CHEMBL2099  [{'accession': 'P07288', 'component_descriptio...
# 2    CHEMBL1250359  [{'accession': 'P26262', 'component_descriptio...
# 3    CHEMBL4105792  [{'accession': 'P14272', 'component_descriptio...
# 4    CHEMBL2111419  [{'accession': 'P03952', 'component_descriptio...
#
#          target_type  tax_id
# 0     SINGLE PROTEIN    9606
# 1     SINGLE PROTEIN    9606
# 2     SINGLE PROTEIN   10090
# 3     SINGLE PROTEIN   10116
# 4  SELECTIVITY GROUP    9606

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL2099'

# %% [markdown]
# **Now retrieve only bioactivity data for target; **Prostate-specific antigen(CHEMBL2099)** with reported IC50  values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#                                          action_type activity_comment  \
# 0                                               None             None
# 1                                               None             None
# 2                                               None             None
# 3  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#    activity_id activity_properties assay_chembl_id  \
# 0     10834399                  []   CHEMBL2016158
# 1     13298715                  []   CHEMBL2383462
# 2     16492067                  []   CHEMBL3774273
# 3     22473290                  []   CHEMBL4685677
# 4     22473292                  []   CHEMBL4685677
#
#                                    assay_description assay_type  \
# 0                   Inhibition of human kallikrein 3          B
# 1                 Inhibition of PSA (unknown origin)          B
# 2  Inhibition of human tissue kallikrein-3 expres...          B
# 3  Inhibition of prostate specific antigen in hum...          B
# 4  Inhibition of prostate specific antigen in hum...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
# 3                    None                   None  BAO_0000190  ...
# 4                    None                   None  BAO_0000190  ...
#
#   target_organism           target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Prostate-specific antigen          9606       None  None
# 1    Homo sapiens  Prostate-specific antigen          9606       None  None
# 2    Homo sapiens  Prostate-specific antigen          9606       None  None
# 3    Homo sapiens  Prostate-specific antigen          9606       None  None
# 4    Homo sapiens  Prostate-specific antigen          9606       None  None
#
#    type units    uo_units upper_value  value
# 0  IC50    nM  UO_0000065        None  226.0
# 1  IC50    nM  UO_0000065        None  226.0
# 2  IC50    uM  UO_0000065        None   13.0
# 3  IC50    uM  UO_0000065        None   0.43
# 4  IC50    uM  UO_0000065        None    1.4
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally Save the resulting bioactivity data to a CSV file** **bioactivity_raw_data.csv**.

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %% [markdown]
# **Now copy "bioactivity_raw_data.csv" file to Google Drive, in folder "data"**

# %%
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 5
# -rw------- 1 root root 4430 Jan 20 21:31 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,10834399,[],CHEMBL2016158,Inhibition of human kallikrein 3,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(OCc1ccccc1)c1cccc(OC(=O)N2C(=O)[C@@H](Cc3ccc(O)cc3)[C@H]2C(=O)OCc2ccccc2)c1,,,CHEMBL2010718,Bioorg Med Chem Lett,2012,"{'bei': '11.75', 'le': '0.22', 'lle': '1.59', 'sei': '5.56'}",CHEMBL2011751,,CHEMBL2011751,6.65,0,http://www.openphacts.org/units/Nanomolar,1632195,=,1,1,=,,IC50,nM,,226.0,CHEMBL2099,Homo sapiens,Prostate-specific antigen,9606,,,IC50,nM,UO_0000065,,226.0
# ,,13298715,[],CHEMBL2383462,Inhibition of PSA (unknown origin),B,,,BAO_0000190,BAO_0000357,single protein format,O=C(OCc1ccccc1)c1cccc(CC(=O)N2C(=O)[C@@H](Cc3ccc(O)cc3)[C@H]2C(=O)OCc2ccccc2)c1,,,CHEMBL2380267,J Med Chem,2013,"{'bei': '11.79', 'le': '0.22', 'lle': '2.02', 'sei': '6.03'}",CHEMBL286934,,CHEMBL286934,6.65,0,http://www.openphacts.org/units/Nanomolar,1894287,=,1,1,=,,IC50,nM,,226.0,CHEMBL2099,Homo sapiens,Prostate-specific antigen,9606,,,IC50,nM,UO_0000065,,226.0
# ,,16492067,[],CHEMBL3774273,Inhibition of human tissue kallikrein-3 expressed in baculovirus infected insect cells using Abz-KLYSSQ-EDDnp as substrate preincubated for 10 mins followed by substrate addition by FRET assay,B,,,BAO_0000190,BAO_0000219,cell-based format,O=C1CC(c2ccc(O)c(O)c2)Oc2c1c(O)cc(O)c2[C@@H]1C(=O)c2c(O)cc(O)cc2O[C@H]1c1ccc(O)cc1,,,CHEMBL3769311,Bioorg Med Chem Lett,2016,"{'bei': '8.75', 'le': '0.16', 'lle': '0.46', 'sei': '2.52'}",CHEMBL446790,FUKUGETIN,CHEMBL446790,4.89,0,http://www.openphacts.org/units/Nanomolar,2759447,=,1,1,=,,IC50,nM,,13000.0,CHEMBL2099,Homo sapiens,Prostate-specific antigen,9606,,,IC50,uM,UO_0000065,,13.0
# "{'action_type': 'INHIBITOR', 'description': 'Negatively effects (inhibits) the normal functioning of the protein e.g., prevention of enzymatic reaction or activation of downstream pathway', 'parent_type': 'NEGATIVE MODULATOR'}",,22473290,[],CHEMBL4685677,Inhibition of prostate specific antigen in human LNCaP cells,B,,,BAO_0000190,BAO_0000219,cell-based format,Brc1ccc(C2Nc3ccc4ccccc4c3C3C=CCC32)cc1,,,CHEMBL4680213,Eur J Med Chem,2020,"{'bei': '16.92', 'le': '0.36', 'lle': '-0.06', 'sei': '52.92'}",CHEMBL4760141,,CHEMBL4760141,6.37,0,http://www.openphacts.org/units/Nanomolar,3522228,=,1,1,=,,IC50,nM,,430.0,CHEMBL2099,Homo sapiens,Prostate-specific antigen,9606,,,IC50,uM,UO_0000065,,0.43
# "{'action_type': 'INHIBITOR', 'description': 'Negatively effects (inhibits) the normal functioning of the protein e.g., prevention of enzymatic reaction or activation of downstream pathway', 'parent_type': 'NEGATIVE MODULATOR'}",,22473292,[],CHEMBL4685677,Inhibition of prostate specific antigen in human LNCaP cells,B,,,BAO_0000190,BAO_0000219,cell-based format,Clc1ccccc1C1Nc2ccc3ccccc3c2C2C=CCC21,,,CHEMBL4680213,Eur J Med Chem,2020,"{'bei': '17.64', 'le': '0.33', 'lle': '-0.47', 'sei': '48.66'}",CHEMBL4797715,,CHEMBL4797715,5.85,0,http://www.openphacts.org/units/Nanomolar,3522231,=,1,1,=,,IC50,nM,,1400.0,CHEMBL2099,Homo sapiens,Prostate-specific antigen,9606,,,IC50,uM,UO_0000065,,1.4
# "{'action_type': 'INHIBITOR', 'description': 'Negatively effects (inhibits) the normal functioning of the protein e.g., prevention of enzymatic reaction or activation of downstream pathway', 'parent_type': 'NEGATIVE MODULATOR'}",,22473293,[],CHEMBL4685677,Inhibition of prostate specific antigen in human LNCaP cells,B,,,BAO_0000190,BAO_0000219,cell-based format,CNC(=O)c1ccc(N2C(=S)N(c3ccc(C#N)c(C(F)(F)F)c3)C(=O)C2(C)C)cc1F,,,CHEMBL4680213,Eur J Med Chem,2020,"{'bei': '14.83', 'le': '0.29', 'lle': '2.90', 'sei': '9.01'}",CHEMBL1082407,ENZALUTAMIDE,CHEMBL1082407,6.89,0,http://www.openphacts.org/units/Nanomolar,3522235,=,1,1,=,,IC50,nM,,130.0,CHEMBL2099,Homo sapiens,Prostate-specific antigen,9606,,,IC50,uM,UO_0000065,,0.13

# %% [markdown]
# # **Step 2: Bioactivity Data Retrieval (IC50)**
# **Retrieve bioactivity data (IC50) for the selected KLK3 target.**

# %% [markdown]
# **Inspect Missing Values**

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Filter Rows with Valid Bioactivity Values**

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#                                          action_type activity_comment  \
# 0                                               None             None
# 1                                               None             None
# 2                                               None             None
# 3  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#    activity_id activity_properties assay_chembl_id  \
# 0     10834399                  []   CHEMBL2016158
# 1     13298715                  []   CHEMBL2383462
# 2     16492067                  []   CHEMBL3774273
# 3     22473290                  []   CHEMBL4685677
# 4     22473292                  []   CHEMBL4685677
#
#                                    assay_description assay_type  \
# 0                   Inhibition of human kallikrein 3          B
# 1                 Inhibition of PSA (unknown origin)          B
# 2  Inhibition of human tissue kallikrein-3 expres...          B
# 3  Inhibition of prostate specific antigen in hum...          B
# 4  Inhibition of prostate specific antigen in hum...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
# 3                    None                   None  BAO_0000190  ...
# 4                    None                   None  BAO_0000190  ...
#
#   target_organism           target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Prostate-specific antigen          9606       None  None
# 1    Homo sapiens  Prostate-specific antigen          9606       None  None
# 2    Homo sapiens  Prostate-specific antigen          9606       None  None
# 3    Homo sapiens  Prostate-specific antigen          9606       None  None
# 4    Homo sapiens  Prostate-specific antigen          9606       None  None
#
#    type units    uo_units upper_value  value
# 0  IC50    nM  UO_0000065        None  226.0
# 1  IC50    nM  UO_0000065        None  226.0
# 2  IC50    uM  UO_0000065        None   13.0
# 3  IC50    uM  UO_0000065        None   0.43
# 4  IC50    uM  UO_0000065        None    1.4
#
# [5 rows x 46 columns]

# %% [markdown]
# **Assign Bioactivity Classes**
# Define active, intermediate, and inactive classes based on IC50 values.

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# **Extract Relevant Columns**

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %% [markdown]
# **Create Preprocessed bioactivity Dataset**

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2011751  O=C(OCc1ccccc1)c1cccc(OC(=O)N2C(=O)[C@@H](Cc3c...
# 1       CHEMBL286934  O=C(OCc1ccccc1)c1cccc(CC(=O)N2C(=O)[C@@H](Cc3c...
# 2       CHEMBL446790  O=C1CC(c2ccc(O)c(O)c2)Oc2c1c(O)cc(O)c2[C@@H]1C...
# 3      CHEMBL4760141             Brc1ccc(C2Nc3ccc4ccccc4c3C3C=CCC32)cc1
# 4      CHEMBL4797715               Clc1ccccc1C1Nc2ccc3ccccc3c2C2C=CCC21
#
#   standard_value bioactivity_class
# 0          226.0            active
# 1          226.0            active
# 2        13000.0          inactive
# 3          430.0            active
# 4         1400.0      intermediate

# %% [markdown]
# **Remove Compounds without Valid SMILES**. Drop rows with **NaN**, **empty** or **None** SMILES values.

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2011751  O=C(OCc1ccccc1)c1cccc(OC(=O)N2C(=O)[C@@H](Cc3c...
# 1       CHEMBL286934  O=C(OCc1ccccc1)c1cccc(CC(=O)N2C(=O)[C@@H](Cc3c...
# 2       CHEMBL446790  O=C1CC(c2ccc(O)c(O)c2)Oc2c1c(O)cc(O)c2[C@@H]1C...
# 3      CHEMBL4760141             Brc1ccc(C2Nc3ccc4ccccc4c3C3C=CCC32)cc1
# 4      CHEMBL4797715               Clc1ccccc1C1Nc2ccc3ccccc3c2C2C=CCC21
#
#   standard_value bioactivity_class
# 0          226.0            active
# 1          226.0            active
# 2        13000.0          inactive
# 3          430.0            active
# 4         1400.0      intermediate

# %% [markdown]
# **Save Preprocessed Bioactivity Data.** Save the cleaned dataset to CSV and copy to Google Drive.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**
